# %%
# === 設定 ===

from pathlib import Path
from datetime import datetime

# ルート
BASE = Path("/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No")   # 変更可
RUN_ROOT = BASE / "20251026_under_25clusters"                                # 変更可

# 出力フォルダ名（未指定なら自動命名）
OUT_NAME = None  # 例: "STEP3.3_onlyMat_20251027"
# OUT_NAME = "STEP3.3_onlyMat_20251027"   # ← 明示したい場合はコメントアウト解除

# 変数リストの与え方を選択：
USE_INLINE_LISTS = False   # True: 下の OH_INLINE / FP_INLINE を使用, False: CSVから読む

# --- インライン指定する場合（USE_INLINE_LISTS=True にした上で編集）---
OH_INLINE = "SMILESsnameinM_PC61BM,SMILESsnameinM_PC71BM,SMILESsnameip1M_AtD,SMILESsnameip1M_BP,SMILESsnameip1M_BP.C60,SMILESsnameip1M_Bu.BP.C60,SMILESsnameip1M_C4DBTA,SMILESsnameip1M_C6DBTA,SMILESsnameip1M_C8DBTA,SMILESsnameip1M_DTA,SMILESsnameip1M_EBDBTA,SMILESsnameip1M_EH.DBTA,SMILESsnameip1M_f.BP.C60,SMILESsnameip1M_r.BP.C60,SMILESsnameip2M_BP,SMILESsnamenM_C60,SMILESsnamenM_DBFIEDOT,SMILESsnamenM_DPc.T,SMILESsnamenM_DPc.mP,SMILESsnamenM_ICEM,SMILESsnamenM_ICMA,SMILESsnamenM_ICMM,SMILESsnamenM_MOPFP,SMILESsnamenM_NC70BA,SMILESsnamenM_NCMA,SMILESsnamenM_NCMM,SMILESsnamenM_PC61BM,SMILESsnamenM_PC71BM,SMILESsnamenM_PCBM,SMILESsnamenM_PFP,SMILESsnamenM_PNDTI.BT,SMILESsnamenM_PNDTI.DTT,SMILESsnamenM_PNDTI.T,SMILESsnamenM_PNDTI.TT,SMILESsnamenM_PTBI2T,SMILESsnamenM_PTBI2TR,SMILESsnamenM_PTBI2Tz,SMILESsnamenM_PTBITT,SMILESsnamenM_TC61BM,SMILESsnamenM_TC61PM,SMILESsnamenM_TFP,SMILESsnamenM_THPc,SMILESsnamep1M_2.2..bithiopheneP1,SMILESsnamep1M_3hexylthieno.3.2b.thiopheneP3,SMILESsnamep1M_3hexylthieno.3.2b.thiopheneP4,SMILESsnamep1M_9triarylamino9HcarbazoleP3,SMILESsnamep1M_ADT,SMILESsnamep1M_AtD,SMILESsnamep1M_BBTzBTIDG,SMILESsnamep1M_BBTzalkylthiopheneBTIDG,SMILESsnamep1M_BDTC6,SMILESsnamep1M_BDTDTKP,SMILESsnamep1M_BDTH1,SMILESsnamep1M_BDTH11,SMILESsnamep1M_BDTH3,SMILESsnamep1M_BDTH6,SMILESsnamep1M_BDTH7,SMILESsnamep1M_BDTH8,SMILESsnamep1M_BDTH9,SMILESsnamep1M_BDTT6,SMILESsnamep1M_BP,SMILESsnamep1M_BPC60,SMILESsnamep1M_BPc,SMILESsnamep1M_BPcpre1,SMILESsnamep1M_BPcpre2,SMILESsnamep1M_BTAnt,SMILESsnamep1M_BTIBDTP2,SMILESsnamep1M_BuBPC60,SMILESsnamep1M_C10DPPBP,SMILESsnamep1M_C2DPPBP,SMILESsnamep1M_C3DPPTTSe,SMILESsnamep1M_C3DPPTTT,SMILESsnamep1M_C3DPPTTTe,SMILESsnamep1M_C4DPPBP,SMILESsnamep1M_C6DPPBP,SMILESsnamep1M_C8DPPBP,SMILESsnamep1M_CPDTDTKP,SMILESsnamep1M_DTA,SMILESsnamep1M_DTAnt,SMILESsnamep1M_DTBT,SMILESsnamep1M_DTPDPP2TBDT,SMILESsnamep1M_DTPDPP2TDBT,SMILESsnamep1M_DTPDPP2TTT,SMILESsnamep1M_DTPDPP3T,SMILESsnamep1M_DTPDPP4T,SMILESsnamep1M_DTPDPPTPT,SMILESsnamep1M_DTSC4,SMILESsnamep1M_DTSC6,SMILESsnamep1M_DTSC6L,SMILESsnamep1M_DTSC8,SMILESsnamep1M_DTSCEH,SMILESsnamep1M_DTSCh,SMILESsnamep1M_DTSChy,SMILESsnamep1M_DTSDC,SMILESsnamep1M_DTST6,SMILESsnamep1M_DTSTCh,SMILESsnamep1M_DTSTChy,SMILESsnamep1M_DTTPTP1,SMILESsnamep1M_DTTPTP2,SMILESsnamep1M_DTTPTP3,SMILESsnamep1M_DTTPTP4,SMILESsnamep1M_DTTPTP5,SMILESsnamep1M_DTTPTP6,SMILESsnamep1M_DTfBT,SMILESsnamep1M_DTffBT,SMILESsnamep1M_EHDBTA,SMILESsnamep1M_F0F0,SMILESsnamep1M_F0F2,SMILESsnamep1M_F1PDPP2TBP,SMILESsnamep1M_F2F0,SMILESsnamep1M_F2F2,SMILESsnamep1M_F2PDPP2TBP,SMILESsnamep1M_FLODTKP,SMILESsnamep1M_P.BDTFBT.,SMILESsnamep1M_P.BDTTBT.,SMILESsnamep1M_P.BDTTTBO.,SMILESsnamep1M_P.BDTTTBT.,SMILESsnamep1M_P.BDTTTFBT.,SMILESsnamep1M_P.BDTTTHBT.,SMILESsnamep1M_P.T32EHiI.,SMILESsnamep1M_P.T3C10iI.,SMILESsnamep1M_P.T3C12iI.,SMILESsnamep1M_P.T3C6iI.,SMILESsnamep1M_P.T3C8iI.,SMILESsnamep1M_P3HNT,SMILESsnamep1M_P3HT,SMILESsnamep1M_P4TBT,SMILESsnamep1M_P4TDPP,SMILESsnamep1M_P4TDTBT,SMILESsnamep1M_P4TPDTQ,SMILESsnamep1M_PBDFDODTBT,SMILESsnamep1M_PBDFDTBO,SMILESsnamep1M_PBDFDTBT,SMILESsnamep1M_PBDFDTBTz,SMILESsnamep1M_PBDFFBT,SMILESsnamep1M_PBDT.DTBSe,SMILESsnamep1M_PBDT.DTBT,SMILESsnamep1M_PBDTBDD,SMILESsnamep1M_PBDTBO,SMILESsnamep1M_PBDTBT,SMILESsnamep1M_PBDTBTz,SMILESsnamep1M_PBDTDPT1,SMILESsnamep1M_PBDTDPT2,SMILESsnamep1M_PBDTDTBTm,SMILESsnamep1M_PBDTDTBTo,SMILESsnamep1M_PBDTDTBTp,SMILESsnamep1M_PBDTDTBTz,SMILESsnamep1M_PBDTDTTTST,SMILESsnamep1M_PBDTFBO,SMILESsnamep1M_PBDTFBT,SMILESsnamep1M_PBDTFQT,SMILESsnamep1M_PBDTFQTT,SMILESsnamep1M_PBDTHDODTHBTffP3,SMILESsnamep1M_PBDTPBO,SMILESsnamep1M_PBDTPDTBT,SMILESsnamep1M_PBDTPODTBO,SMILESsnamep1M_PBDTPODTBT,SMILESsnamep1M_PBDTPOFBT,SMILESsnamep1M_PBDTT10TPD,SMILESsnamep1M_PBDTT12TPD,SMILESsnamep1M_PBDTT8TPD,SMILESsnamep1M_PBDTTBO,SMILESsnamep1M_PBDTTBT,SMILESsnamep1M_PBDTTDPP,SMILESsnamep1M_PBDTTDTBO,SMILESsnamep1M_PBDTTDTBT,SMILESsnamep1M_PBDTTDTBTz,SMILESsnamep1M_PBDTTDTTBT,SMILESsnamep1M_PBDTTEHDTEHBTffP2,SMILESsnamep1M_PBDTTEHDTHBTffP1,SMILESsnamep1M_PBDTTFBSe,SMILESsnamep1M_PBDTTFDPP,SMILESsnamep1M_PBDTTFTTE,SMILESsnamep1M_PBDTTPD,SMILESsnamep1M_PBDTTPDP1,SMILESsnamep1M_PBDTTPDP2,SMILESsnamep1M_PBDTTPDP3,SMILESsnamep1M_PBDTTS1,SMILESsnamep1M_PBDTTS2,SMILESsnamep1M_PBDTTS3,SMILESsnamep1M_PBDTTSeDPP,SMILESsnamep1M_PBDTTTBT,SMILESsnamep1M_PBDTTTC,SMILESsnamep1M_PBDTTTCF,SMILESsnamep1M_PBDTTTE,SMILESsnamep1M_PBDTTTS,SMILESsnamep1M_PBDTTTST,SMILESsnamep1M_PBPT12,SMILESsnamep1M_PBQ1,SMILESsnamep1M_PBQ2,SMILESsnamep1M_PBQ3,SMILESsnamep1M_PBQ4,SMILESsnamep1M_PBT0F,SMILESsnamep1M_PBT1F,SMILESsnamep1M_PBT2F,SMILESsnamep1M_PBT3F,SMILESsnamep1M_PBTPyDPP,SMILESsnamep1M_PBTff4T2OD,SMILESsnamep1M_PBnDTFTAZ,SMILESsnamep1M_PBnDTHTAZ,SMILESsnamep1M_PCBTDPP,SMILESsnamep1M_PCDTBT,SMILESsnamep1M_PCDTBX,SMILESsnamep1M_PCDTDPP,SMILESsnamep1M_PCDTPT,SMILESsnamep1M_PCDTPX,SMILESsnamep1M_PCDTQx,SMILESsnamep1M_PCDTTPP,SMILESsnamep1M_PCPDTBT,SMILESsnamep1M_PCPTDO,SMILESsnamep1M_PCTDPP,SMILESsnamep1M_PCV,SMILESsnamep1M_PCVT,SMILESsnamep1M_PCVTT,SMILESsnamep1M_PCVTTTT,SMILESsnamep1M_PCz,SMILESsnamep1M_PDPP2FTC12,SMILESsnamep1M_PDPP2FTC14,SMILESsnamep1M_PDPP2FTC16,SMILESsnamep1M_PDPP2T,SMILESsnamep1M_PDPP2TBP,SMILESsnamep1M_PDPP3T,SMILESsnamep1M_PDPP3TaltTPT,SMILESsnamep1M_PDPPBBT,SMILESsnamep1M_PDPPBT,SMILESsnamep1M_PDPPTPT,SMILESsnamep1M_PDPPTVT,SMILESsnamep1M_PDTPDTDPP,SMILESsnamep1M_PDTPDTDPPBu,SMILESsnamep1M_PDTST,SMILESsnamep1M_PDTSTPD,SMILESsnamep1M_PEN,SMILESsnamep1M_PFBTBDT,SMILESsnamep1M_PFDTBT,SMILESsnamep1M_PFDTDPP,SMILESsnamep1M_PGFDTBT,SMILESsnamep1M_PGFDTDPPC4S25,SMILESsnamep1M_PGFDTDPPC8,SMILESsnamep1M_PICDTBT,SMILESsnamep1M_PIDTTFBSe,SMILESsnamep1M_PNNT12DT,SMILESsnamep1M_PNNT12HD,SMILESsnamep1M_PNNTDT,SMILESsnamep1M_PNOz4T,SMILESsnamep1M_PNPz4T,SMILESsnamep1M_PNT4T2OD,SMILESsnamep1M_PNTz4T,SMILESsnamep1M_PNTz4TF2,SMILESsnamep1M_PNTz4TF4,SMILESsnamep1M_PPDT2FBT,SMILESsnamep1M_PPDTBT,SMILESsnamep1M_PPDTFBT,SMILESsnamep1M_PQT12,SMILESsnamep1M_PSBTBT,SMILESsnamep1M_PSEHTT,SMILESsnamep1M_PTB1,SMILESsnamep1M_PTB2,SMILESsnamep1M_PTB3,SMILESsnamep1M_PTB4,SMILESsnamep1M_PTB5,SMILESsnamep1M_PTB6,SMILESsnamep1M_PTB7,SMILESsnamep1M_PTB7Th,SMILESsnamep1M_PTBDTDTBT,SMILESsnamep1M_PTBDTffDTBT,SMILESsnamep1M_PTBF0,SMILESsnamep1M_PTBF1,SMILESsnamep1M_PTBF2,SMILESsnamep1M_PTBF3,SMILESsnamep1M_PTBFTDTBT,SMILESsnamep1M_PTBI2T,SMILESsnamep1M_PTBI2TR,SMILESsnamep1M_PTBI2Tz,SMILESsnamep1M_PTBITT,SMILESsnamep1M_PTzBT10HD,SMILESsnamep1M_PTzBT10OD,SMILESsnamep1M_PTzBT12HD,SMILESsnamep1M_PTzBT12OD,SMILESsnamep1M_PTzBT14HD,SMILESsnamep1M_PTzBT14OD,SMILESsnamep1M_PTzBTBOBO,SMILESsnamep1M_PTzBTBOHD,SMILESsnamep1M_PTzBTBOOD,SMILESsnamep1M_PTzBTEHHD,SMILESsnamep1M_PTzBTEHOD,SMILESsnamep1M_PTzBTHD,SMILESsnamep1M_PTzQT14,SMILESsnamep1M_PeNPz2T,SMILESsnamep1M_PeNPz3T,SMILESsnamep1M_PeNPz4T,SMILESsnamep1M_PffBT4T2OD,SMILESsnamep1M_PhBADT,SMILESsnamep1M_Poly.N9.fheptadecanyl2.7carbazolealt5.5.4.f.7.fdi2.thienyl..1.2.5.oxadiazolo.3.4d.pyridazine.P1,SMILESsnamep1M_Poly.N9.fheptadecanyl2.7carbazolealt5.5.4.f.7.fdi2thienyl.2.3dioctylpyrazino.2.3d.pyridazine.P2,SMILESsnamep1M_Poly.N9.fheptadecanyl2.7carbazolealt5.5.4.f.7.fdi2thienyl.pyrazino.2.3d.pyridazine.P3,SMILESsnamep1M_RanPBDPPT,SMILESsnamep1M_RegPBDPPT,SMILESsnamep1M_TDPPBBT,SMILESsnamep1M_TPDBr16,SMILESsnamep1M_Thieno.3.4c.pyrrole4.6dioneP1,SMILESsnamep1M_Thieno.3.4c.pyrrole4.6dioneP2,SMILESsnamep1M_Thieno.3.4c.pyrrole4.6dioneP3,SMILESsnamep1M_TzTzBTIDG,SMILESsnamep1M_TzTzalkylthiopheneBTIDG,SMILESsnamep1M_VacdepoBPc,SMILESsnamep1M_fBPC60,SMILESsnamep1M_pBTTT,SMILESsnamep1M_rBPC60,SMILESsnamep1M_ranPDPPTPDalt2T,SMILESsnamep1M_regPDPPTPDalt2T,SMILESsnamep1M_thieno.3.2b.thiopheneP2,SMILESsnamep2M_PBDTTFTTE"  # 例；空でもOK
FP_INLINE = "X100.1,X100.3,X100.4,X101.3,X101.4,X101.5,X102.4,X105,X105.1,X105.3,X105.4,X107.4,X108.1,X108.3,X108.4,X109.1,X109.3,X109.4,X110.3,X110.4,X111.3,X111.4,X112.1,X112.3,X112.4,X113.3,X113.4,X114.1,X114.3,X114.4,X115.1,X115.3,X115.4,X116.3,X116.4,X117.4,X118.1,X118.3,X118.4,X119.4,X120.3,X120.4,X121.1,X121.3,X121.4,X122.3,X122.4,X123.3,X123.4,X124.4,X125.3,X125.4,X126.3,X127.3,X127.4,X128.1,X128.3,X128.4,X129.1,X129.3,X129.4,X130.4,X131.1,X131.3,X131.4,X132.3,X132.4,X133.4,X134.4,X135.4,X136.4,X137.3,X137.4,X138.3,X138.4,X139.4,X140.4,X141.1,X141.4,X142.3,X142.4,X143.3,X143.4,X144.3,X144.4,X145.3,X145.4,X146.3,X146.4,X147.1,X147.3,X147.4,X148.4,X149.1,X149.3,X149.4,X150.1,X150.3,X150.4,X151.1,X151.3,X151.4,X152.3,X152.4,X153.1,X153.3,X153.4,X154.3,X154.4,X155.1,X155.3,X155.4,X157.3,X157.4,X158.1,X158.3,X158.4,X159.3,X159.4,X160.1,X160.3,X160.4,X161.1,X161.3,X161.4,X162.4,X163.3,X163.4,X164.1,X164.3,X164.4,X165,X165.1,X165.2,X165.3,X165.4,X165.5,X166.4,X17.1,X17.4,X19.3,X19.4,X20.4,X22.3,X22.4,X26.1,X26.3,X26.4,X3.4,X30.4,X33.4,X34.4,X36.1,X36.3,X36.4,X44.3,X44.4,X45.4,X46.4,X47.3,X47.4,X50.1,X50.3,X50.4,X51.4,X52.4,X57.4,X58.4,X59.4,X62.1,X62.3,X62.4,X64.4,X65.3,X65.4,X66.4,X67.4,X70.4,X71.4,X72.4,X73.4,X74.4,X76.4,X77.4,X79.3,X79.4,X80.4,X83.3,X85.4,X86.3,X86.4,X88.1,X88.3,X88.4,X89.4,X90.4,X91.4,X93.3,X94.4,X95.4,X96.3,X97.4,X98.3,X98.4,X99.3,X99.4"                     # 例；空でもOK

# --- CSVから読む場合（USE_INLINE_LISTS=False のとき使用）---
OH_LIST_CSV = BASE / "features_OH_onlyMat.csv"
FP_LIST_CSV = BASE / "features_FP_onlyMat.csv"

# 変数名の一致モード（"exact" or "contains"）
MATCH_MODE = "exact"  # 通常は "exact" 推奨。不一致が続くときだけ "contains" を試す

# %%
import pandas as pd
import numpy as np

NAME_HINTS = [
    "variable","var","name","feature","feat","column","col","field",
    "descriptor","smiles","sname","id","xid","token","label"
]

def norm_series(s: pd.Series) -> pd.Series:
    return (
        s.astype(str)
         .str.strip()
         .str.replace(r"\s+", " ", regex=True)
         .str.replace("\u3000", " ")  # 全角空白対策
    )

def parse_csv_list_text(s: str) -> set:
    if not s or not str(s).strip():
        return set()
    items = [x.strip() for x in str(s).split(",")]
    items = [x for x in items if x != ""]
    return set(items)

def candidate_name_columns(df: pd.DataFrame):
    cols = list(df.columns)
    hinted = [c for c in cols if any(h in str(c).lower() for h in NAME_HINTS)]
    if df.columns[0] not in hinted:
        hinted = [df.columns[0]] + hinted
    out = []
    for c in hinted + cols:
        if c not in out:
            out.append(c)
    return out

def choose_best_name_col(df: pd.DataFrame, keep_set: set, match_mode: str = "exact"):
    best_col, best_hits = None, -1
    stats = []
    for c in candidate_name_columns(df):
        s = norm_series(df[c])
        if match_mode == "exact":
            hits = int(s.isin(keep_set).sum())
        else:
            # containsモードは簡易評価（速度重視）
            ks = list(keep_set)
            sample = s if len(s) <= 2000 else s.sample(2000, random_state=0)
            hits = 0
            for v in sample:
                if any(k in v for k in ks):
                    hits += 1
            # 簡易スケール補正
            hits = int(hits * (len(s) / max(1, len(sample))))
        stats.append((c, hits))
        if hits > best_hits:
            best_col, best_hits = c, hits
    stats.sort(key=lambda x: x[1], reverse=True)
    return best_col, best_hits, stats

def read_keep_set_from_csv(p: Path) -> set:
    df = pd.read_csv(p)
    # 最もユニーク数が多い列を“名前列”として採用（素性CSVの列名が不明でもOK）
    best_col, best_u = None, -1
    for c in df.columns:
        u = df[c].nunique(dropna=True)
        if u > best_u:
            best_col, best_u = c, u
    return set(norm_series(df[best_col]).tolist())

# %%
# keepセットの準備
if USE_INLINE_LISTS:
    keep_OH = set(norm_series(pd.Series(list(parse_csv_list_text(OH_INLINE)))))
    keep_FP = set(norm_series(pd.Series(list(parse_csv_list_text(FP_INLINE)))))
else:
    keep_OH = read_keep_set_from_csv(OH_LIST_CSV)
    keep_FP = read_keep_set_from_csv(FP_LIST_CSV)

print(f"keep_OH: {len(keep_OH)} features")
print(f"keep_FP: {len(keep_FP)} features")

# 出力ルート
if OUT_NAME is None or str(OUT_NAME).strip() == "":
    OUT_NAME = f"STEP3.3_onlyMat_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
OUT_ROOT = RUN_ROOT / OUT_NAME
OUT_OH = OUT_ROOT / "OH" / "04_assignments_onlyMat"
OUT_FP = OUT_ROOT / "FP" / "04_assignments_onlyMat"
OUT_LOGS = OUT_ROOT / "logs"

for p in [OUT_OH, OUT_FP, OUT_LOGS]:
    p.mkdir(parents=True, exist_ok=True)

OUT_ROOT, OUT_OH, OUT_FP, OUT_LOGS
# Out:
# keep_OH: 1046 features
# keep_FP: 1046 features
# (PosixPath('/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_onlyMat_20251027_180229'),
#  PosixPath('/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_onlyMat_20251027_180229/OH/04_assignments_onlyMat'),
#  PosixPath('/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_onlyMat_20251027_180229/FP/04_assignments_onlyMat'),
#  PosixPath('/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_onlyMat_20251027_180229/logs'))

# %%
from pathlib import Path

def filter_one_file(in_path: Path, keep_set: set, out_dir: Path, match_mode: str = "exact"):
    df = pd.read_csv(in_path)
    if df.empty:
        return {
            "input_file": str(in_path),
            "output_file": "",
            "name_col_used": "",
            "match_mode": match_mode,
            "n_rows_before": 0,
            "n_rows_after": 0,
            "n_dropped": 0,
            "overlap_hits_on_used_col": 0,
            "side": "",
            "note": "empty_input_df"
        }
    if len(keep_set) == 0:
        return {
            "input_file": str(in_path),
            "output_file": "",
            "name_col_used": "",
            "match_mode": match_mode,
            "n_rows_before": len(df),
            "n_rows_after": 0,
            "n_dropped": len(df),
            "overlap_hits_on_used_col": 0,
            "side": "",
            "note": "empty_keep_set"
        }

    name_col, hits, stats = choose_best_name_col(df, keep_set, match_mode)
    s = norm_series(df[name_col])
    if match_mode == "exact":
        mask = s.isin(keep_set)
    else:
        mask = s.apply(lambda v: any(k in v for k in keep_set))

    before = len(df)
    df2 = df.loc[mask].copy()
    after = len(df2)

    out_path = out_dir / (in_path.stem + "_onlyMat" + in_path.suffix)
    df2.to_csv(out_path, index=False, encoding="utf-8-sig")

    rec = {
        "input_file": str(in_path),
        "output_file": str(out_path),
        "name_col_used": name_col,
        "match_mode": match_mode,
        "n_rows_before": before,
        "n_rows_after": after,
        "n_dropped": before - after,
        "overlap_hits_on_used_col": int(hits),
        "top_namecol_candidates": [{"col": c, "hits": h} for c,h in stats[:5]]
    }
    return rec

# %%
# 入力探索（再帰）
files_oh = sorted(RUN_ROOT.glob("**/OH/04_assignments/ClusterAssign_*_OH_*.csv"))
files_fp = sorted(RUN_ROOT.glob("**/FP/04_assignments/ClusterAssign_*_FP_*.csv"))

logs = []

# OH 側
if len(keep_OH) > 0:
    for f in files_oh:
        try:
            rec = filter_one_file(f, keep_OH, OUT_OH, MATCH_MODE)
            rec["side"] = "OH"
            logs.append(rec)
        except Exception as e:
            logs.append({"side":"OH","input_file":str(f),"error":str(e)})

# FP 側
if len(keep_FP) > 0:
    for f in files_fp:
        try:
            rec = filter_one_file(f, keep_FP, OUT_FP, MATCH_MODE)
            rec["side"] = "FP"
            logs.append(rec)
        except Exception as e:
            logs.append({"side":"FP","input_file":str(f),"error":str(e)})

log_df = pd.DataFrame(logs)
log_df.to_csv(OUT_LOGS / "filter_onlyMat_index_ALL.csv", index=False, encoding="utf-8-sig")
log_df.to_json(OUT_LOGS / "filter_onlyMat_index_ALL.json", orient="records", force_ascii=False, indent=2)

# 空出力の注意喚起
empty = log_df[(log_df.get("n_rows_after").fillna(0) == 0)]
if not empty.empty:
    empty.to_csv(OUT_LOGS / "ATTN_empty_outputs.csv", index=False, encoding="utf-8-sig")

print("=== Done ===")
print("OUT_ROOT:", OUT_ROOT)
print("OH out  :", OUT_OH)
print("FP out  :", OUT_FP)
print("Logs    :", OUT_LOGS)

display(log_df.head(10))
# Out:
# === Done ===
# OUT_ROOT: /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_onlyMat_20251027_180229
# OH out  : /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_onlyMat_20251027_180229/OH/04_assignments_onlyMat
# FP out  : /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_onlyMat_20251027_180229/FP/04_assignments_onlyMat
# Logs    : /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_onlyMat_20251027_180229/logs
#                                           input_file  \
# 0  /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/c...
# 1  /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/c...
# 2  /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/c...
# 3  /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/c...
# 4  /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/c...
# 5  /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/c...
# ...

# %%
# 空出力だったファイルの上位候補列・ヒット数を一覧
try:
    diag_cols = ["side","input_file","name_col_used","overlap_hits_on_used_col","n_rows_before","n_rows_after","top_namecol_candidates"]
    display(log_df.loc[log_df.get("n_rows_after").fillna(0)==0, diag_cols].head(20))
except Exception:
    pass
# Out:
# Empty DataFrame
# Columns: [side, input_file, name_col_used, overlap_hits_on_used_col, n_rows_before, n_rows_after, top_namecol_candidates]
# Index: []
