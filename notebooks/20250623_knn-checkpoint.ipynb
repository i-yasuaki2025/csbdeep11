# %%
# --- ライブラリ読み込み ---
if (!require(caret)) install.packages("caret"); library(caret)
if (!require(Metrics)) install.packages("Metrics"); library(Metrics)
if (!require(ggplot2)) install.packages("ggplot2"); library(ggplot2)

# --- データ読み込み ---
data_path <- "/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/20220127_PLS 202201 ALL/n_base.csv"
data_all <- read.csv(data_path, row.names = 1)

# --- 目的変数名 ---
target_vars <- c("Jsc", "Voc", "FF", "PCEmax")

# --- 結果とプロットの保存先 ---
results_list <- list()
plots_list <- list()

for (target in target_vars) {
  cat("=============================\n")
  cat("Target:", target, "\n")
  cat("=============================\n")

  # --- 欠損処理とスケーリング ---
  data_clean <- data_all[complete.cases(data_all[, target]), ]
  y <- data_clean[[target]]
  X <- data_clean[, !(colnames(data_clean) %in% target_vars)]
  X <- X[, sapply(X, function(x) sd(x, na.rm = TRUE) != 0)]
  X_scaled <- scale(X)
  data_model <- data.frame(y = y, X_scaled)

  # --- モデル学習（10-fold CV）---
  set.seed(42)
  model <- train(
    y ~ .,
    data = data_model,
    method = "knn",
    tuneLength = 10,
    trControl = trainControl(method = "cv", number = 10)
  )

  # --- 予測と評価 ---
  pred <- predict(model, newdata = data_model)
  r2 <- cor(y, pred)^2
  rmse_val <- RMSE(pred, y)
  mae_val <- MAE(pred, y)
  sd_y <- sd(y)
  rpd_val <- sd_y / rmse_val
  tss <- sum((y - mean(y))^2)
  press <- sum((y - pred)^2)
  q2_val <- 1 - (press / tss)

  # --- 評価表示 ---
  cat(sprintf("R2      = %.4f\n", r2))
  cat(sprintf("corALL  = %.4f\n", sqrt(r2)))
  cat(sprintf("RMSE    = %.4f\n", rmse_val))
  cat(sprintf("MAE     = %.4f\n", mae_val))
  cat(sprintf("RPD     = %.4f\n", rpd_val))
  cat(sprintf("Q2      = %.4f\n", q2_val))

  # --- プロット作成 ---
  df_plot <- data.frame(Observed = y, Predicted = pred)
  p <- ggplot(df_plot, aes(x = Observed, y = Predicted)) +
    geom_point(color = "darkred", alpha = 0.7, size = 2) +
    geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "gray") +
    coord_fixed() +
    theme_minimal() +
    labs(title = paste("Prediction of", target, "(knn)"),
         x = "Observed", y = "Predicted")

  print(p)
  ggsave(filename = paste0("plot_knn_", target, ".pdf"), plot = p, width = 6, height = 6)

  # --- 結果保存 ---
  results_list[[target]] <- list(model = model, R2 = r2, RMSE = rmse_val, MAE = mae_val, RPD = rpd_val, Q2 = q2_val)
  plots_list[[target]] <- p
}
cat("\n--- Best k values for each target ---\n")
for (target in target_vars) {
  best_k <- results_list[[target]]$model$bestTune$k
  cat(sprintf("Target: %-7s -> Best k = %d\n", target, best_k))
}


# --- CSV出力 ---
summary_df <- do.call(rbind, lapply(names(results_list), function(tgt) {
  cbind(Target = tgt, as.data.frame(results_list[[tgt]][-1]))
}))
write.csv(summary_df, "knn_summary.csv", row.names = FALSE)
# Out:
# =============================
# Target: Jsc
# =============================
# R2      = 0.7150
# corALL  = 0.8456
# RMSE    = 2.7047
# MAE     = 2.0160
# RPD     = 1.8707
# Q2      = 0.7135
# =============================
# Target: Voc
# =============================
# R2      = 0.8665
# corALL  = 0.9309
# RMSE    = 0.0554
# MAE     = 0.0369
# RPD     = 2.7369
# Q2      = 0.8661
# =============================
# Target: FF
# =============================
# plot without title
# R2      = 0.5971
# corALL  = 0.7727
# RMSE    = 0.0707
# MAE     = 0.0534
# RPD     = 1.5759
# Q2      = 0.5962
# =============================
# Target: PCEmax
# =============================
# plot without title
# R2      = 0.6824
# corALL  = 0.8261
# RMSE    = 1.4910
# MAE     = 1.1173
# RPD     = 1.7731
# Q2      = 0.6810
# plot without title
# --- Best k values for each target ---
# Target: Jsc     -> Best k = 5
# Target: Voc     -> Best k = 5
# Target: FF      -> Best k = 5
# Target: PCEmax  -> Best k = 5
# plot without title

# %%
# 必要なパッケージの読み込み
library(caret)
library(Metrics)
library(ggplot2)
library(lattice)

# 対象ファイル名一覧
file_names <- c(
  "n_base.csv", "n_base_OH.csv", "n_base_FP.csv",
  "n_all.csv", "n_all_OH.csv", "n_all_FP.csv",
  "m_base.csv", "m_base_OH.csv", "m_base_FP.csv",
  "m_all.csv", "m_all_OH.csv", "m_all_FP.csv"
)

# データパスの共通部分
base_path <- "/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/20220127_PLS 202201 ALL/"

# モデルの出力用日付
today <- format(Sys.Date(), "%Y%m%d")

# 評価結果格納用データフレーム
result_matrix <- matrix(nrow = 5, ncol = length(file_names))
rownames(result_matrix) <- c("Best_k", "R2_PCEmax", "RMSE_PCEmax", "MAE_PCEmax", "RPD_PCEmax")
colnames(result_matrix) <- file_names

# 軸スケール決定関数
get_axis_limit <- function(values) {
  max_val <- max(values, na.rm = TRUE)
  if (max_val <= 1.5) {
    return(ceiling(max_val / 0.1) * 0.1)
  } else if (max_val <= 5) {
    return(ceiling(max_val / 0.5) * 0.5)
  } else if (max_val <= 30) {
    return(ceiling(max_val / 2) * 2)
  } else {
    return(ceiling(max_val / 5) * 5)
  }
}

#--- メインループ ---#
for (file in file_names) {
  filepath <- paste0(base_path, file)
  cat("\n=== Processing:", file, "===\n")
  df_all <- read.csv(filepath)
  cat("Final dataset size:", dim(df_all)[1], dim(df_all)[2], "\n")

  # 説明変数と目的変数
  target_vars <- c("Jsc", "Voc", "FF", "PCEmax")
  feature_vars <- setdiff(colnames(df_all), target_vars)

  for (target_var in target_vars) {
    cat("\n---\nTraining model for:", target_var, "on", file, "\n")
    df <- df_all[complete.cases(df_all[[target_var]]), c(feature_vars, target_var)]

    # モデルチューニング：k値を1〜30で探索
    tune_grid <- expand.grid(k = 1:30)
    ctrl <- trainControl(method = "cv", number = 10)

    model <- train(
      formula(paste(target_var, "~ .")),
      data = df,
      method = "knn",
      metric = "RMSE",
      trControl = ctrl,
      tuneGrid = tune_grid
    )

    # 予測と評価指標
    pred <- predict(model, df)
    obs <- df[[target_var]]

    R2 <- round(cor(pred, obs)^2, 3)
    RMSE_val <- round(rmse(obs, pred), 3)
    MAE_val <- round(mae(obs, pred), 3)
    RPD_val <- round(sd(obs) / RMSE_val, 3)

    cat("Best k value:", model$bestTune$k, "\n")
    cat(file, target_var, ": R2 =", R2, ", RMSE =", RMSE_val, ", MAE =", MAE_val, ", RPD =", RPD_val, "\n")

    # PCEmax の結果のみ保存
    if (target_var == "PCEmax") {
      result_matrix["Best_k", file] <- model$bestTune$k
      result_matrix["R2_PCEmax", file] <- R2
      result_matrix["RMSE_PCEmax", file] <- RMSE_val
      result_matrix["MAE_PCEmax", file] <- MAE_val
      result_matrix["RPD_PCEmax", file] <- RPD_val
    }

    # 軸範囲
    range_max <- get_axis_limit(c(obs, pred))

    # プロット
    p <- ggplot(data.frame(Predicted = pred, Observed = obs), aes(x = Observed, y = Predicted)) +
      geom_point(color = "blue", alpha = 0.7) +
      geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
      scale_x_continuous(limits = c(0, range_max)) +
      scale_y_continuous(limits = c(0, range_max)) +
      coord_fixed(ratio = 1) +
      labs(
        title = paste0(target_var, " Prediction (", file, ")"),
        x = "Observed",
        y = "Predicted",
        subtitle = paste0("R² = ", R2, ", RMSE = ", RMSE_val, ", MAE = ", MAE_val, ", RPD = ", RPD_val)
      ) +
      theme_minimal()

    print(p)
  }
}

# 結果の保存
write.csv(result_matrix, paste0("knn_summary_", today, ".csv"), row.names = TRUE)
cat("\nSummary saved as knn_summary_", today, ".csv\n")
# Out:
# === Processing: n_base.csv ===
# Final dataset size: 358 12
#
# ---
# Training model for: Jsc on n_base.csv
# Best k value: 2
# n_base.csv Jsc : R2 = 0.936 , RMSE = 1.276 , MAE = 0.869 , RPD = 3.965
#
# ---
# Training model for: Voc on n_base.csv
# Best k value: 3
# n_base.csv Voc : R2 = 0.869 , RMSE = 0.055 , MAE = 0.034 , RPD = 2.757
#
# ---
# Training model for: FF on n_base.csv
# plot without title
# Best k value: 2
# n_base.csv FF : R2 = 0.858 , RMSE = 0.042 , MAE = 0.031 , RPD = 2.654
#
# ---
# Training model for: PCEmax on n_base.csv
# plot without title
# Best k value: 2
# n_base.csv PCEmax : R2 = 0.934 , RMSE = 0.68 , MAE = 0.5 , RPD = 3.888
#
# === Processing: n_base_OH.csv ===
# Final dataset size: 358 143
#
# ---
# Training model for: Jsc on n_base_OH.csv
# plot without title
# Best k value: 8
# n_base_OH.csv Jsc : R2 = 0.751 , RMSE = 2.531 , MAE = 1.877 , RPD = 1.999
#
# ---
# Training model for: Voc on n_base_OH.csv
# plot without title
# Best k value: 1
# n_base_OH.csv Voc : R2 = 1 , RMSE = 0 , MAE = 0 , RPD = Inf
#
# ---
# Training model for: FF on n_base_OH.csv
# plot without title
# Best k value: 3
# n_base_OH.csv FF : R2 = 0.706 , RMSE = 0.061 , MAE = 0.042 , RPD = 1.827
#
# ---
# Training model for: PCEmax on n_base_OH.csv
# plot without title
# Best k value: 5
# n_base_OH.csv PCEmax : R2 = 0.727 , RMSE = 1.387 , MAE = 1.006 , RPD = 1.906
#
# === Processing: n_base_FP.csv ===
# Final dataset size: 358 200
#
# ---
# Training model for: Jsc on n_base_FP.csv
