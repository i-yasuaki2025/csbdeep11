# %%
import shutil
from pathlib import Path

# ==== 設定 ====
# 移動したいフォルダ（誤出力フォルダ）を3つ指定
src_folders = [
    "/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/STEP3.1",
    "/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/STEP3.2_U25_signlessCorr_MDS_20251027",
    "/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/STEP3.3_U25_20251027",
]

# 共通の移動先フォルダ
dst_root = Path("/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters")

# ==== 実行 ====
dst_root.mkdir(parents=True, exist_ok=True)

for src in src_folders:
    src_path = Path(src)
    if not src_path.exists():
        print(f"⚠️ Not found: {src_path}")
        continue

    dst_path = dst_root / src_path.name  # 元のフォルダ名を保持して移動
    shutil.copytree(src_path, dst_path, dirs_exist_ok=True)
    print(f"✅ Copied: {src_path} → {dst_path}")
# Out:
# ✅ Copied: /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/STEP3.1 → /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.1
# ✅ Copied: /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/STEP3.2_U25_signlessCorr_MDS_20251027 → /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.2_U25_signlessCorr_MDS_20251027
# ✅ Copied: /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/STEP3.3_U25_20251027 → /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_U25_20251027

# %%
import shutil
from pathlib import Path

# ==== 設定 ====
# 移動したいフォルダ（誤出力フォルダ）を3つ指定
src_folders = [
    "/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/STEP3.3_U25_20251027_correct"
]

# 共通の移動先フォルダ
dst_root = Path("/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters")

# ==== 実行 ====
dst_root.mkdir(parents=True, exist_ok=True)

for src in src_folders:
    src_path = Path(src)
    if not src_path.exists():
        print(f"⚠️ Not found: {src_path}")
        continue

    dst_path = dst_root / src_path.name  # 元のフォルダ名を保持して移動
    shutil.copytree(src_path, dst_path, dirs_exist_ok=True)
    print(f"✅ Copied: {src_path} → {dst_path}")
# Out:
# ✅ Copied: /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/STEP3.3_U25_20251027_correct → /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/cal_cluster_No/20251026_under_25clusters/STEP3.3_U25_20251027_correct

# %%
STEP3.3_U25_20251027_correct
