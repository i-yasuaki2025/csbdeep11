# %%
if(!require(pls)){
  install.packages("pls");library(pls)
}
if(!require(plsVarSel)){
  install.packages("plsVarSel");library(plsVarSel)
}

#[1]
ifname <- "DataMerge20211213.csv"
readData <- read.delim(ifname, header=T,sep=",",row.names=1,as.is=TRUE,strip.white=FALSE)
nf1<-dim(readData)[2]
charaCheck<-rep(FALSE,nf1)
for(i in 1:nf1){
  charaCheck[i]<-!is.character(readData[,i])
}
readData2<-readData[,charaCheck]
#[2]
yname<-"Jsc"     #"Jsc","Voc","FF","PCEmax"
Y<-readData2[,yname]
rmlist<-c("Jsc","Voc","FF","PCEmax","PCEcal", "PCEdiff", "PCEave")
collist<-colnames(readData2)
Xnames<-setdiff(collist, rmlist)
X<-readData2[,c(Xnames)]
#---
Nadata<-is.na(X)
# Out:
# Warning message in file(file, "rt"):
# "cannot open file 'DataMerge20211213.csv': No such file or directory"
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 2. file(file, "rt")
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "cannot open the connection", base::quote(file(file, "rt")))

# %%
NNa<-apply(Nadata,2,sum)
mNNA<-max(NNa)
hist(NNa,breaks=seq(0,mNNA+1,1))
# Out:
# Error: object 'Nadata' not found
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'Nadata' not found", base::quote(eval(expr, envir)))

# %%
XX<-X[,NNa==0] #~100 変化
dim(XX)
#---
dMerge<-data.frame(Y,XX)
Nadata<-na.omit(dMerge)
#[3]
sdcheck<-apply(Nadata,2,sd)
TF<-(sdcheck!=0)
ssd<-scale(Nadata[,TF])
ssd[,1]<-Nadata[,1]
#[4]
YXXdata<-data.frame(ssd)
#----------------------------------------------------------------
aa<-c(567,574,575,576,577,585,586,587)

YXdata<-YXXdata[-c(aa),] #
YXdata
dim(YXdata)
# Out:
# Error: object 'X' not found
# Traceback:

# %%
result1.pls<-plsr(Y~.,data=YXdata,scale=FALSE,validation="LOO")
names(result1.pls)
plspress<-result1.pls$validation$PRESS
ncomponent<-which.min(plspress)
#---[sum((dataUsed$Y-Ypred1)^2) == plspress]--------------------
Ypred1<-result1.pls$validation$pred[,,ncomponent]
#[5]--- Q2
tss<-sum((YXdata[,1]-mean(YXdata[,1]))^2)
Q2<-1-plspress/tss
mc<-which.max(Q2)
par(cex=1.0)
barplot(Q2[1:20],names.arg=1:20)
corLOO<-cor(YXdata[,1],Ypred1)
titleR<-paste0(yname,": # of comps = ",mc, " Q2= ",substring(max(Q2),1,5),
               " corLOO= ",substring(corLOO,1,5))
par(cex=1.0)
par(mar=c(5,5,5,5))
plot(YXdata[,1],Ypred1,xlab="original", ylab="prediction",main=titleR)
#[6]------------------------------------------
Ypred2<-predict(result1.pls,newdata=YXdata, ncomp = ncomponent)
rss<-sum((YXdata[,1]-Ypred2)^2)
R2<-1-rss/tss
CR<-cor(YXdata[,1],Ypred2)
titleR<-paste0(yname,": R2= ",substring(R2,1,5)," corALL= ",substring(CR,1,5))
par(cex=1.0)
par(mar=c(5,5,5,5))
plot(YXdata[,1],Ypred2,xlab="original",ylab="prediction",main=titleR)
#[7]---------------------------------------
par(cex=0.5)
par(mar=c(5,20,1,1))
corR<-sort(coefficients(result1.pls,ncomp=ncomponent)[,1,1],decreasing=TRUE)
barplot(corR,horiz=TRUE,las=1)
abline(v=0,lty=1)
# Out:
# Error in eval(mf, parent.frame()): object 'YXdata' not found
# Traceback:
#
# 1. eval(cl, parent.frame())
# 2. eval(cl, parent.frame())
# 3. pls::mvr(Y ~ ., data = YXdata, scale = FALSE, validation = "LOO",
#  .     method = "kernelpls")
# 4. eval(mf, parent.frame())
# 5. eval(mf, parent.frame())
# 6. model.frame(formula = Y ~ ., data = YXdata)
# 7. model.frame.default(formula = Y ~ ., data = YXdata)
# 8. is.data.frame(data)
# 9. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'YXdata' not found", base::quote(eval(mf, parent.frame())))

# %%
#チェック
#Ypred2
#aa2<-Ypred2[Ypred2>50]#予測値オーバー
#bb2<-which(Ypred2>50)
#aa2
#bb2
YXdata[,1]
aa3<-YXdata[,1][YXdata[,1]>50]#
bb3<-which(YXdata[,1]>50)
aa3
bb3
# Out:
# Error: object 'YXdata' not found
# Traceback:

# %%
YXdata<-dataYXXdata[-c(bb),]
dim(YXdata)
# Out:
# Error: object 'dataYXXdata' not found
# Traceback:

# %%
#----------------------------------------------------------------
result1.pls<-plsr(Y~.,data=YXdata,scale=FALSE,validation="LOO")
names(result1.pls)
plspress<-result1.pls$validation$PRESS
ncomponent<-which.min(plspress)
#---[sum((dataUsed$Y-Ypred1)^2) == plspress]--------------------
Ypred1<-result1.pls$validation$pred[,,ncomponent]
#[5]--- Q2
tss<-sum((YXdata[,1]-mean(YXdata[,1]))^2)
Q2<-1-plspress/tss
mc<-which.max(Q2)
par(cex=1.0)
barplot(Q2[1:20],names.arg=1:20)
corLOO<-cor(YXdata[,1],Ypred1)
titleR<-paste0(yname,": # of comps = ",mc, " Q2= ",substring(max(Q2),1,5),
               " corLOO= ",substring(corLOO,1,5))
par(cex=1.0)
par(mar=c(5,5,5,5))
plot(YXdata[,1],Ypred1,xlab="original", ylab="prediction",main=titleR)
#[6]------------------------------------------
Ypred2<-predict(result1.pls,newdata=YXdata, ncomp = ncomponent)
rss<-sum((YXdata[,1]-Ypred2)^2)
R2<-1-rss/tss
CR<-cor(YXdata[,1],Ypred2)
titleR<-paste0(yname,": R2= ",substring(R2,1,5)," corALL= ",substring(CR,1,5))
par(cex=1.0)
par(mar=c(5,5,5,5))
plot(YXdata[,1],Ypred2,xlab="original",ylab="prediction",main=titleR)
#[7]---------------------------------------
par(cex=0.5)
par(mar=c(5,20,1,1))
corR<-sort(coefficients(result1.pls,ncomp=ncomponent)[,1,1],decreasing=TRUE)
barplot(corR,horiz=TRUE,las=1)
abline(v=0,lty=1)
# Out:
# Error in eval(mf, parent.frame()): object 'YXdata' not found
# Traceback:
#
# 1. eval(cl, parent.frame())
# 2. eval(cl, parent.frame())
# 3. pls::mvr(Y ~ ., data = YXdata, scale = FALSE, validation = "LOO",
#  .     method = "kernelpls")
# 4. eval(mf, parent.frame())
# 5. eval(mf, parent.frame())
# 6. model.frame(formula = Y ~ ., data = YXdata)
# 7. model.frame.default(formula = Y ~ ., data = YXdata)
# 8. is.data.frame(data)
# 9. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'YXdata' not found", base::quote(eval(mf, parent.frame())))

# %%
#[1]
ifname <- "DataMerge20211213.csv"
readData <- read.delim(ifname, header=T,sep=",",row.names=1,as.is=TRUE,strip.white=FALSE)
nf1<-dim(readData)[2]
charaCheck<-rep(FALSE,nf1)
for(i in 1:nf1){
  charaCheck[i]<-!is.character(readData[,i])
}
readData2<-readData[,charaCheck]
#[2]
yname<-"Jsc"     #"Jsc","Voc","FF","PCEmax"
Y<-readData2[,yname]
rmlist<-c("Jsc","Voc","FF","PCEmax","PCEcal", "PCEdiff", "PCEave")
collist<-colnames(readData2)
Xnames<-setdiff(collist, rmlist)
X<-readData2[,c(Xnames)]
#---
Nadata<-is.na(X)

NNa<-apply(Nadata,2,sum)
mNNA<-max(NNa)
hist(NNa,breaks=seq(0,mNNA+1,1))

XX<-X[,NNa>=2] #~100 変化
dim(XX)
#---
dMerge<-data.frame(Y,XX)
Nadata<-na.omit(dMerge)
#[3]
sdcheck<-apply(Nadata,2,sd)
TF<-(sdcheck!=0)
ssd<-scale(Nadata[,TF])
ssd[,1]<-Nadata[,1]
#[4]
YXXdata<-data.frame(ssd)
#----------------------------------------------------------------
aa<-c(567,574,575,576,577,585,586,587)

YXdata<-YXXdata[-c(aa),] #
YXdata
dim(YXdata)
result1.pls<-plsr(Y~.,data=YXdata,scale=FALSE,validation="LOO")
names(result1.pls)
plspress<-result1.pls$validation$PRESS
ncomponent<-which.min(plspress)
#---[sum((dataUsed$Y-Ypred1)^2) == plspress]--------------------
Ypred1<-result1.pls$validation$pred[,,ncomponent]
#[5]--- Q2
tss<-sum((YXdata[,1]-mean(YXdata[,1]))^2)
Q2<-1-plspress/tss
mc<-which.max(Q2)
par(cex=1.0)
barplot(Q2[1:20],names.arg=1:20)
corLOO<-cor(YXdata[,1],Ypred1)
titleR<-paste0(yname,": # of comps = ",mc, " Q2= ",substring(max(Q2),1,5),
               " corLOO= ",substring(corLOO,1,5))
par(cex=1.0)
par(mar=c(5,5,5,5))
plot(YXdata[,1],Ypred1,xlab="original", ylab="prediction",main=titleR)
#[6]------------------------------------------
Ypred2<-predict(result1.pls,newdata=YXdata, ncomp = ncomponent)
rss<-sum((YXdata[,1]-Ypred2)^2)
R2<-1-rss/tss
CR<-cor(YXdata[,1],Ypred2)
titleR<-paste0(yname,": R2= ",substring(R2,1,5)," corALL= ",substring(CR,1,5))
par(cex=1.0)
par(mar=c(5,5,5,5))
plot(YXdata[,1],Ypred2,xlab="original",ylab="prediction",main=titleR)
#[7]---------------------------------------
par(cex=0.5)
par(mar=c(5,20,1,1))
corR<-sort(coefficients(result1.pls,ncomp=ncomponent)[,1,1],decreasing=TRUE)
barplot(corR,horiz=TRUE,las=1)
abline(v=0,lty=1)
# Out:
# Warning message in file(file, "rt"):
# "cannot open file 'DataMerge20211213.csv': No such file or directory"
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 2. file(file, "rt")
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "cannot open the connection", base::quote(file(file, "rt")))
