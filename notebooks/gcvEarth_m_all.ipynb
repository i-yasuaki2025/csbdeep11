# %%
if(!require(caret)){
  install.packages("caret")
  library(caret)
}

#setwd("~/Desktop")
if(!require(rcdk)){
  install.packages("rcdk")
  library(rcdk)
}
if(!require(fingerprint)){
  install.packages("fingerprint")
  library(fingerprint)
}

if(!require(pls)){
  install.packages("pls")
  library(pls)
}
if(!require(Metrics)){
  install.packages("Metrics")
  library(Metrics)
}
if(!require(monmlp)){
  install.packages("monmlp")
  library(monmlp)
}

if(!require(frbs)){
install.packages("frbs")
library(frbs)
}

if(!require(Rborist)){    
install.packages("Rborist")
library(Rborist)
}
if(!require(xgboost)){
install.packages("xgboost")
library(xgboost)
}
if(!require(RWeka)){    
install.packages("RWeka")
library(RWeka)
}

if(!require(RWekajars)){    
install.packages("RWekajars")
library(RWekajars)
}
    
if(!require(extraTrees)){    
install.packages("extraTrees")
library(extraTrees)
}
    
    
if(!require(randomForest)){    
install.packages("randomForest")
library(randomForest)
}
datanamelist<-c("m_all_noSMILES.csv","m_all_ohSMILES.csv","m_all_FPSMILES.csv")

dataNumVar<-length(datanamelist)
for (dataname in datanamelist) {
   
    ifname01<-c(dataname)
    #ifname02<-c("n_base_ohSMILES.csv")
    #ifname03<-c("n_base_FPSMILES.csv")
    #ifname04<-c("n_all_noSMILES.csv")
    #ifname05<-c("n_all_ohSMILES.csv")
    #ifname06<-c("n_all_FPSMILES.csv")
    #ifname07<-c("m_base_noSMILES.csv")
    #ifname08<-c("m_base_ohSMILES.csv")
    #ifname09<-c("m_base_FPSMILES.csv")
    #ifname10<-c("m_all_noSMILES.csv")
    #ifname11<-c("m_all_ohSMILES.csv")
    #ifname12<-c("m_all_FPSMILES.csv")

    dataUsed01<-read.delim(ifname01,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed02<-read.delim(ifname02,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed03<-read.delim(ifname03,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed04<-read.delim(ifname04,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed05<-read.delim(ifname05,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed06<-read.delim(ifname06,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed07<-read.delim(ifname07,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed08<-read.delim(ifname08,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed09<-read.delim(ifname09,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed10<-read.delim(ifname10,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed11<-read.delim(ifname11,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  
    #dataUsed12<-read.delim(ifname12,row.names=1,header=T,sep=",",as.is=TRUE,strip.white=FALSE)  

    #datalistVar<-c("dataUsed01","dataUsed02","dataUsed03","dataUsed04","dataUsed05","dataUsed06","dataUsed07","dataUsed08","dataUsed09","dataUsed10","dataUsed11","dataUsed12")
    #dataNumVar<-length(datalistVar)

    
    
    tt01<-which(apply(dataUsed01,2,sd)==0)
    length(tt01)
    if (length(tt01)>0){
        dataUsed02<-dataUsed01[,-tt01]
     }else{ dataUsed02<-dataUsed01
    }
    listVar<-c("Jsc","Voc","FF","PCEmax")
    NumVar<-length(listVar)

    dataUsed02noVar<-data.frame(dataUsed02[, -which (colnames(dataUsed02)%in%listVar)])
    dataUsed02Var<-dataUsed02[,listVar]
    dataUsed02noVarS<-scale(dataUsed02noVar)
    



    dataUsed03<-data.frame(dataUsed02Var,dataUsed02noVarS)
    dim(dataUsed03)
    dataUsed03NA<-dataUsed03[!is.na(dataUsed03$PCEmax), ]
    dataUsed03NA
    
    

    dataUsed04<-dataUsed03NA[, colSums(is.na(dataUsed03NA)) != nrow(dataUsed03NA)]
    
    
    dataUsed04t<-t(dataUsed04)
    dataUsed05<-data.frame(t(na.omit(dataUsed04t)))
    
    #dataUsed05<-na.omit(dataUsed04)
    #dataUsed05<-data.frame(t(na.omit(dataUsed04t)))

    NS<-dim(dataUsed05)[1]
    NF<-dim(dataUsed05)[2]
    #[1]NA check
    vnaTF<-!is.na(dataUsed05)
    nonNA<-sum(vnaTF)
    RnonNA<-nonNA/(NS*NF)
    
    Usedataname<-c("Final.csv")
    write.csv(dataUsed04,Usedataname)
    
    set.data<-data.frame(dataUsed05)
        #ListAR<-c("lars")
    #ListAR<-c("nnls","kknn",)
    #ListAR<-c("brnn","gaussprLinear","gaussprRadial","gcvEarth","knn","M5Rules","monmlp","ppr","Rborist","svmLinear","svmRadialCost","WM")
    ListAR<-c("gcvEarth")
    #ListAR<-c("xgbLinear","xgbDART","M5Rules","M5","extraTrees","rf")
    NumAR<-length(ListAR)
    x <- matrix(nrow=NumVar, ncol=NumAR)
    rownames(x) <- listVar
    colnames(x) <- ListAR

 
    
    
    listVar<-c("Jsc","Voc","FF","PCEmax")
    NumVar<-length(listVar)

        for (i in 1:NumVar) {
          set.mesureVar<-i #1:Jsc,2:Voc,3,FF,4:PCE

          mindex01<-set.data[,set.mesureVar]
          #mindex<-alldata[,3]  #<-1
          nf01<-dim(set.data)[2]  
          set.data01<-data.frame(mindex01,set.data[, -which (colnames(set.data)%in%listVar)])

          dimdata<-dim(set.data01)

          nf02<-dim(set.data01)[2]

          #========== Set Y ==========
          yset01<-1 
          #===========================
          yname01<-colnames(set.data01[yset01])
          ydata01<-set.data01[,yset01]
          #-------------------------

          xname01<-colnames(set.data01)[2:nf02]
          xdata01<- set.data01[,-yset01]

          dimdata1<-c(dimdata[[1]])
          dimdata2<-c(dimdata[[2]])

          #bb<-as.formula(paste("mindex01","~",".", sep=""))
          #-----------------------------


          #for(j in seq_along(ARList)){}  
          #for (j in 1:NumAR) {
          for(modelname in ListAR){
            #results.nnet<-train(bb,data=dataUsed03,method=modelname, trControl=trainControl(method="LOOCV"))
            try(results.nnet<-train(mindex01~.,data=set.data01,method=modelname, trControl=trainControl(method="LOOCV")))

            try(est.Y<-predict(results.nnet,set.data01))

            try(fdata01<-data.frame(ydata01,est.Y))
            try(RMSE01<-rmse(ydata01,est.Y))
            try(R<-cor(ydata01,est.Y))
            try(R2<-R^2)

            try(s01 <- paste(dataname,listVar[set.mesureVar], modelname,":r2 = ",sprintf("%5.3f",R2),":RMSE = ",sprintf("%5.3f",RMSE01),"sample:",sprintf("%s",dimdata1),"valiable:",sprintf("%s",dimdata2)))
            s02<-paste("Data:",sprintf("%s",ifname01))

            #plot(ydata01, est.Y,main=s01,sub=s02)
            #x[i,1]<-cor(ydata01,est.Y)
            # write.csv(x,"ddd.csv")

            s03 <- paste(ifname01,listVar[set.mesureVar],modelname,".pdf")
            pdf(s03)
            try(plot(ydata01, est.Y,main=s01,sub=s02))
            try(x[i,1]<-cor(ydata01,est.Y))
            dev.off()
        }
      }
    }
# Out:
# Loading required package: caret
#
# Loading required package: ggplot2
#
# Loading required package: lattice
#
# Warning message in system("timedatectl", intern = TRUE):
# "running command 'timedatectl' had status 1"
# Loading required package: rcdk
#
# Loading required package: rcdklibs
#
# Loading required package: rJava
#
# Loading required package: fingerprint
#
# Loading required package: pls
#
#
# Attaching package: 'pls'
#
#
# The following object is masked from 'package:caret':
#
#     R2
#
#
# The following object is masked from 'package:stats':
#
#     loadings
#
#
# Loading required package: Metrics
#
#
# Attaching package: 'Metrics'
#
#
# The following objects are masked from 'package:caret':
#
#     precision, recall
#
#
# Loading required package: monmlp
#
# Loading required package: optimx
#
# Loading required package: frbs
#
# Loading required package: Rborist
#
# Rborist 0.2-3
#
# Type RboristNews() to see new features/changes/bug fixes.
#
# Loading required package: xgboost
#
# Loading required package: RWeka
#
# Loading required package: RWekajars
#
# Loading required package: extraTrees
#
# Loading required package: randomForest
#
# randomForest 4.6-14
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: 'randomForest'
#
#
# The following object is masked from 'package:ggplot2':
#
#     margin
#
#
# Loading required package: earth
#
# Loading required package: Formula
#
# Loading required package: plotmo
#
# Loading required package: plotrix
#
# Loading required package: TeachingDemos
#
# Warning message:
# "model fit failed for Fold0001: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0002: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0003: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0006: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0007: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0008: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0010: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0012: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0014: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0018: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0021: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0025: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0026: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0027: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0028: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0029: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0032: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0033: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0035: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0041: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0043: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0045: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0047: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0048: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0050: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0051: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0052: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0054: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0055: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0056: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0057: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0060: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0061: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0062: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0063: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0065: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0067: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0070: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0071: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0073: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0075: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0076: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0081: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0082: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0086: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0087: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0088: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0091: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0092: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0096: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0098: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0099: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0100: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.24881364271401):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 0.78184898881419):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.21283468793303):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 3.21037378415098):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.22379259809754):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 4.33933752613208):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 5.88120330992436):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 6.03809430343392):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 7.14300369626114):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 1.12577156284775):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 5.99241443065971):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 5.05729030414177):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = -0.524836838007871):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.76608858467851):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 3.69506144368248):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.40275755155463):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 1.89849826908484):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 6.58037243378638):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 6.48521940165436):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.3244782635988):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 4.67872299064115):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 1.80822937854662):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 4.61202229770898):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 5.49611567463016):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.45154544902395):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.60757764754727):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.50254726254683):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 2.93408912090012):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 5.04342549700044):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 4.07736212554792):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 14.3381263397213):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 12.6079637272386):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 12.9821388776394):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 11.5595659252909):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 13.3868912628651):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 14.2475539393322):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 16.9312613452955):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 14.6794397809052):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 7.36240898177812):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 10.8309233823537):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 11.5547135012188):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 9.54401973396162):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 12.2185113576859):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 3.32609051819145):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 5.93742543416344):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 5.28413003283493):
# "invalid factor level, NA generated"
# Warning message in `[<-.factor`(`*tmp*`, ri, value = 5.7108872263547):
# "invalid factor level, NA generated"
# Warning message:
# "model fit failed for Fold0101: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0102: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0103: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0105: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0106: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0108: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0109: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0110: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0111: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0115: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0117: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0118: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0120: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0121: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0122: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0123: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0124: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0125: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0126: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0128: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0132: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0133: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0134: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0137: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0139: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0140: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0141: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0142: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0145: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold0146: degree=1 Error in leaps.setup(x = bx, y = y, force.in = 1, force.out = NULL, intercept = FALSE,  :
#   NA/NaN/Inf in foreign function call (arg 3)
# "
# Warning message:
# "model fit failed for Fold