# %%
import os
import json
import joblib
import numpy as np
import pandas as pd
from datetime import datetime

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error


# =========================
# Config
# =========================
SEED = 42
np.random.seed(SEED)

base_path = "/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/20220127_PLS 202201 ALL/20251216_for_making_collect_data_nm_baseall_OHFP_csv/rebuilt_merged_data/"

file_names = [
    "n_base.csv", "n_base_OH_rebuilt.csv", "n_base_FP_rebuilt.csv",
    "n_all.csv",  "n_all_OH_rebuilt.csv",  "n_all_FP_rebuilt.csv",
    "m_base.csv", "m_base_OH_rebuilt.csv", "m_base_FP_rebuilt.csv",
    "m_all.csv",  "m_all_OH_rebuilt.csv",  "m_all_FP_rebuilt.csv"
]

target_vars = ["Jsc", "Voc", "FF", "PCEmax"]
today = datetime.now().strftime("%Y%m%d")

output_dir = f"./{today}_Rebuilt_12Files_RboristLikeRF_Train_CV10OOF_OOD"
os.makedirs(output_dir, exist_ok=True)


# =========================
# Helpers
# =========================
def rmse(y_true, y_pred) -> float:
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))

def safe_r2(y_true, y_pred) -> float:
    try:
        return float(r2_score(y_true, y_pred))
    except Exception:
        return float("nan")

def create_ood_split(df: pd.DataFrame, feature_cols, ood_ratio=0.1):
    """重心からの距離が大きい 10% を OOD にする"""
    X = df[feature_cols].to_numpy()
    centroid = np.mean(X, axis=0)
    distances = np.linalg.norm(X - centroid, axis=1)
    num_ood = max(1, int(len(df) * ood_ratio))
    ood_idx = np.argsort(distances)[-num_ood:]
    df_train = df.drop(df.index[ood_idx])
    df_ood = df.iloc[ood_idx]
    return df_train, df_ood

def remove_zero_variance(df: pd.DataFrame, cols):
    v = df[cols].var(axis=0, skipna=True)
    keep = v[(v > 0) & (~v.isna())].index.tolist()
    return keep

def remove_collinear_features(df: pd.DataFrame, cols, threshold=0.99999):
    """相関がほぼ1の重複特徴を削除"""
    if len(cols) < 2:
        return cols
    corr = df[cols].corr().abs().fillna(0.0)
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    to_drop = [c for c in upper.columns if (upper[c] > threshold).any()]
    if to_drop:
        print(f"  [Cleaning] Removed {len(to_drop)} duplicated features (corr>{threshold})")
    return [c for c in cols if c not in to_drop]

def overfit_flags(train_r2, cv_r2, train_rmse, cv_rmse,
                  r2_gap_thr=0.10, rmse_gap_ratio_thr=0.10):
    """Train vs CV10_OOF の差で Overfit を判定（Rコードと同じルール）"""
    if np.isnan(train_r2) or np.isnan(cv_r2) or np.isnan(train_rmse) or np.isnan(cv_rmse):
        return False, "OK"
    delta_r2 = train_r2 - cv_r2
    delta_rmse = cv_rmse - train_rmse
    flag = (delta_r2 >= r2_gap_thr) or (
        (train_rmse > 0) and (delta_rmse >= rmse_gap_ratio_thr * abs(train_rmse))
    )
    label = "Overfit_suspected" if flag else "OK"
    return flag, label, float(delta_r2), float(delta_rmse)

def build_oof_predictions_rf(best_params, X_train, y_train, n_splits=10):
    """ベストパラメータで RandomForest の CV10 OOF 予測を作る"""
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    oof = np.full(shape=(X_train.shape[0],), fill_value=np.nan, dtype=float)

    for fold, (tr, va) in enumerate(kf.split(X_train), start=1):
        model = RandomForestRegressor(
            random_state=SEED,
            n_jobs=-1,
            **best_params
        )
        model.fit(X_train[tr], y_train.iloc[tr])
        oof[va] = model.predict(X_train[va])

    return oof


# =========================
# Main
# =========================
summary_rows = []
importance_rows = []

print(f"[INFO] Output dir: {output_dir}")
print(f"[INFO] Input base path: {base_path}")

for file in file_names:
    in_path = os.path.join(base_path, file)
    if not os.path.exists(in_path):
        print(f"[WARN] Skipping: {file} (Not found)")
        continue

    print(f"\n=== Processing Rborist-like RF: {file} ===")
    try:
        df_raw = pd.read_csv(in_path, index_col=0)
        df_raw = df_raw.drop(columns=["X"], errors="ignore")
    except Exception as e:
        print(f"[ERROR] read_csv failed: {file} | {e}")
        continue

    # 数値列のみ & 欠損除去
    df_num = df_raw.select_dtypes(include=[np.number]).dropna()
    if df_num.shape[0] < 20:
        print(f"  [WARN] Too few rows after dropna: {df_num.shape[0]}")
        continue

    for target in target_vars:
        if target not in df_num.columns:
            continue

        # ✅ features = 「4つの目的変数をすべて除外」
        feature_cols = [c for c in df_num.columns if c not in target_vars]
        feature_cols = remove_zero_variance(df_num, feature_cols)
        feature_cols = remove_collinear_features(df_num, feature_cols, threshold=0.99999)

        if len(feature_cols) == 0 or df_num.shape[0] < 20:
            continue

        # OOD split
        df_train, df_ood = create_ood_split(df_num, feature_cols, ood_ratio=0.1)

        # Scaling (-1, 1)  ※ R と同じ発想
        scaler = MinMaxScaler(feature_range=(-1, 1))
        X_train = scaler.fit_transform(df_train[feature_cols])
        y_train = df_train[target]
        X_ood = scaler.transform(df_ood[feature_cols])
        y_ood = df_ood[target]

        # -------------------------
        # Hyperparameter tuning (Rborist 相当のランダムフォレスト)
        # -------------------------
        base_rf = RandomForestRegressor(
            random_state=SEED,
            n_jobs=-1
        )

        param_grid = {
            "n_estimators": [200, 500],
            "max_depth": [None, 20, 40],
            "min_samples_leaf": [1, 3, 5],
            "max_features": ["sqrt", 0.3, 0.5]
        }

        cv = KFold(n_splits=10, shuffle=True, random_state=SEED)
        grid = GridSearchCV(
            estimator=base_rf,
            param_grid=param_grid,
            scoring="neg_root_mean_squared_error",
            cv=cv,
            n_jobs=-1,
            refit=True
        )

        try:
            grid.fit(X_train, y_train)
        except Exception as e:
            print(f"  [ERROR] GridSearch failed Target={target}: {e}")
            continue

        best_model = grid.best_estimator_
        best_params = grid.best_params_

        # -------------------------
        # Train / CV10_OOF / OOD
        # -------------------------
        # Train
        pred_train = best_model.predict(X_train)
        train_r2 = safe_r2(y_train, pred_train)
        train_rmse = rmse(y_train, pred_train)
        train_mae = float(mean_absolute_error(y_train, pred_train))
        train_rpd = float(np.std(y_train) / train_rmse) if train_rmse != 0 else 0.0

        # CV10_OOF
        pred_oof = build_oof_predictions_rf(best_params, X_train, y_train, n_splits=10)
        cv_r2 = safe_r2(y_train, pred_oof)
        cv_rmse = rmse(y_train, pred_oof)
        cv_mae = float(mean_absolute_error(y_train, pred_oof))
        cv_rpd = float(np.std(y_train) / cv_rmse) if cv_rmse != 0 else 0.0

        # OOD
        pred_ood = best_model.predict(X_ood)
        ood_r2 = safe_r2(y_ood, pred_ood)
        ood_rmse = rmse(y_ood, pred_ood)
        ood_mae = float(mean_absolute_error(y_ood, pred_ood))
        ood_rpd = float(np.std(y_ood) / ood_rmse) if ood_rmse != 0 else 0.0

        overfit_flag, overfit_label, delta_r2, delta_rmse = overfit_flags(
            train_r2, cv_r2, train_rmse, cv_rmse,
            r2_gap_thr=0.10,
            rmse_gap_ratio_thr=0.10
        )

        summary_rows.append({
            "File": file,
            "Target": target,
            "Train_R2": train_r2,
            "Train_RMSE": train_rmse,
            "Train_MAE": train_mae,
            "Train_RPD": train_rpd,
            "CV10_R2": cv_r2,
            "CV10_RMSE": cv_rmse,
            "CV10_MAE": cv_mae,
            "CV10_RPD": cv_rpd,
            "OOD_R2": ood_r2,
            "OOD_RMSE": ood_rmse,
            "OOD_MAE": ood_mae,
            "OOD_RPD": ood_rpd,
            "n_samples": int(df_num.shape[0]),
            "n_features": int(len(feature_cols)),
            "Best_Params": json.dumps(best_params, ensure_ascii=False),
            "Overfit_Flag": bool(overfit_flag),
            "Overfit_Label": overfit_label,
            "Delta_R2_TrainMinusCV10": delta_r2,
            "Delta_RMSE_CV10MinusTrain": delta_rmse
        })

        print(
            f"  Target={target} | "
            f"Train_R2={train_r2:.3f} | CV10_R2={cv_r2:.3f} | OOD_R2={ood_r2:.3f} | {overfit_label}"
        )

        # -------------------------
        # Save model bundle
        # -------------------------
        bundle = {
            "model": best_model,
            "scaler": scaler,
            "feature_cols": feature_cols,
            "target": target,
            "file": file,
            "best_params": best_params
        }
        model_name = f"fixed_{today}_RboristLikeRF_model_{file.replace('.csv','')}_{target}.joblib"
        joblib.dump(bundle, os.path.join(output_dir, model_name))

        # -------------------------
        # Save prediction CSV (Train / CV10_OOF / OOD_Test) identical columns
        # -------------------------
        df_pred_train = pd.DataFrame({
            "SampleID": df_train.index.astype(str),
            "Observed": y_train.to_numpy(),
            "Predicted": pred_train.astype(float),
            "Type": ["Train"] * len(y_train)
        })
        df_pred_oof = pd.DataFrame({
            "SampleID": df_train.index.astype(str),
            "Observed": y_train.to_numpy(),
            "Predicted": pred_oof.astype(float),
            "Type": ["CV10_OOF"] * len(y_train)
        })
        df_pred_ood = pd.DataFrame({
            "SampleID": df_ood.index.astype(str),
            "Observed": y_ood.to_numpy(),
            "Predicted": pred_ood.astype(float),
            "Type": ["OOD_Test"] * len(y_ood)
        })

        df_pred_all = pd.concat(
            [df_pred_train, df_pred_oof, df_pred_ood],
            axis=0,
            ignore_index=True
        )
        pred_name = f"fixed_{today}_RboristLikeRF_{file.replace('.csv','')}_{target}_pred.csv"
        df_pred_all.to_csv(os.path.join(output_dir, pred_name), index=False)

        # -------------------------
        # Feature importance (Gini-based)
        # -------------------------
        importances = best_model.feature_importances_
        order = np.argsort(importances)[::-1]
        for idx in order:
            imp_val = float(importances[idx])
            if imp_val <= 0:
                continue
            importance_rows.append({
                "File": file,
                "Target": target,
                "Feature": feature_cols[idx],
                "Importance_Mean": imp_val,
                "Importance_Std": float("nan")  # RFの標準 importance なので std は無し
            })

# =========================
# Save summary / importance
# =========================
df_sum = pd.DataFrame(summary_rows)
sum_path = os.path.join(output_dir, f"fixed_{today}_RboristLikeRF_summary.csv")
df_sum.to_csv(sum_path, index=False)

df_imp = pd.DataFrame(importance_rows)
imp_path = os.path.join(output_dir, f"fixed_{today}_RboristLikeRF_feature_importance.csv")
df_imp.to_csv(imp_path, index=False)

print("\n[DONE]")
print(f"Summary : {sum_path}")
print(f"Imp     : {imp_path}")
# Out:
# [INFO] Output dir: ./20251218_Rebuilt_12Files_RboristLikeRF_Train_CV10OOF_OOD
# [INFO] Input base path: /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/20220127_PLS 202201 ALL/20251216_for_making_collect_data_nm_baseall_OHFP_csv/rebuilt_merged_data/
#
# === Processing Rborist-like RF: n_base.csv ===
#   Target=Jsc | Train_R2=0.860 | CV10_R2=0.690 | OOD_R2=0.597 | Overfit_suspected
#   Target=Voc | Train_R2=0.927 | CV10_R2=0.802 | OOD_R2=0.649 | Overfit_suspected
#   Target=FF | Train_R2=0.774 | CV10_R2=0.500 | OOD_R2=-0.808 | Overfit_suspected
#   Target=PCEmax | Train_R2=0.833 | CV10_R2=0.649 | OOD_R2=0.714 | Overfit_suspected
#
# === Processing Rborist-like RF: n_base_OH_rebuilt.csv ===
#   Target=Jsc | Train_R2=0.900 | CV10_R2=0.742 | OOD_R2=0.529 | Overfit_suspected
#   Target=Voc | Train_R2=0.940 | CV10_R2=0.806 | OOD_R2=0.682 | Overfit_suspected
#   Target=FF | Train_R2=0.805 | CV10_R2=0.529 | OOD_R2=-0.278 | Overfit_suspected
#   Target=PCEmax | Train_R2=0.881 | CV10_R2=0.713 | OOD_R2=0.679 | Overfit_suspected
#
# === Processing Rborist-like RF: n_base_FP_rebuilt.csv ===
#   [Cleaning] Removed 46 duplicated features (corr>0.99999)
#   Target=Jsc | Train_R2=0.869 | CV10_R2=0.685 | OOD_R2=0.740 | Overfit_suspected
#   [Cleaning] Removed 46 duplicated features (corr>0.99999)
#   Target=Voc | Train_R2=0.938 | CV10_R2=0.820 | OOD_R2=0.731 | Overfit_suspected
#   [Cleaning] Removed 46 duplicated features (corr>0.99999)
#   Target=FF | Train_R2=0.781 | CV10_R2=0.485 | OOD_R2=-0.163 | Overfit_suspected
#   [Cleaning] Removed 46 duplicated features (corr>0.99999)
#   Target=PCEmax | Train_R2=0.846 | CV10_R2=0.635 | OOD_R2=0.700 | Overfit_suspected
#
# === Processing Rborist-like RF: n_all.csv ===
#   [Cleaning] Removed 9 duplicated features (corr>0.99999)
#   Target=Jsc | Train_R2=0.909 | CV10_R2=0.561 | OOD_R2=0.216 | Overfit_suspected
#   [Cleaning] Removed 9 duplicated features (corr>0.99999)
#   Target=Voc | Train_R2=0.954 | CV10_R2=0.711 | OOD_R2=-0.099 | Overfit_suspected
#   [Cleaning] Removed 9 duplicated features (corr>0.99999)
#   Target=FF | Train_R2=0.860 | CV10_R2=0.389 | OOD_R2=0.101 | Overfit_suspected
#   [Cleaning] Removed 9 duplicated features (corr>0.99999)
#   Target=PCEmax | Train_R2=0.742 | CV10_R2=0.461 | OOD_R2=0.083 | Overfit_suspected
#
# === Processing Rborist-like RF: n_all_OH_rebuilt.csv ===
#   [Cleaning] Removed 12 duplicated features (corr>0.99999)
#   Target=Jsc | Train_R2=0.932 | CV10_R2=0.585 | OOD_R2=0.292 | Overfit_suspected
#   [Cleaning] Removed 12 duplicated features (corr>0.99999)
#   Target=Voc | Train_R2=0.957 | CV10_R2=0.709 | OOD_R2=-0.178 | Overfit_suspected
#   [Cleaning] Removed 12 duplicated features (corr>0.99999)
#   Target=FF | Train_R2=0.877 | CV10_R2=0.403 | OOD_R2=0.121 | Overfit_suspected
#   [Cleaning] Removed 12 duplicated features (corr>0.99999)
#   Target=PCEmax | Train_R2=0.905 | CV10_R2=0.476 | OOD_R2=0.320 | Overfit_suspected
#
# === Processing Rborist-like RF: n_all_FP_rebuilt.csv ===
#   [Cleaning] Removed 46 duplicated features (corr>0.99999)
#   Target=Jsc | Train_R2=0.796 | CV10_R2=0.615 | OOD_R2=0.367 | Overfit_suspected
#   [Cleaning] Removed 46 duplicated features (corr>0.99999)
#   Target=Voc | Train_R2=0.958 | CV10_R2=0.735 | OOD_R2=0.373 | Overfit_suspected
#   [Cleaning] Removed 46 duplicated features (corr>0.99999)
#   Target=FF | Train_R2=0.865 | CV10_R2=0.420 | OOD_R2=0.234 | Overfit_suspected
#   [Cleaning] Removed 46 duplicated features (corr>0.99999)
#   Target=PCEmax | Train_R2=0.763 | CV10_R2=0.554 | OOD_R2=0.422 | Overfit_suspected
#
# === Processing Rborist-like RF: m_base.csv ===
#   Target=Jsc | Train_R2=0.888 | CV10_R2=0.458 | OOD_R2=-0.005 | Overfit_suspected
#   Target=Voc | Train_R2=0.907 | CV10_R2=0.424 | OOD_R2=0.528 | Overfit_suspected
#   Target=FF | Train_R2=0.854 | CV10_R2=0.280 | OOD_R2=0.161 | Overfit_suspected
#   Target=PCEmax | Train_R2=0.883 | CV10_R2=0.467 | OOD_R2=-0.127 | Overfit_suspected
#
# === Processing Rborist-like RF: m_base_OH_rebuilt.csv ===
#   Target=Jsc | Train_R2=0.922 | CV10_R2=0.613 | OOD_R2=0.269 | Overfit_suspected
#   Target=Voc | Train_R2=0.937 | CV10_R2=0.602 | OOD_R2=0.461 | Overfit_suspected
#   Target=FF | Train_R2=0.881 | CV10_R2=0.476 | OOD_R2=0.158 | Overfit_suspected
#   Target=PCEmax | Train_R2=0.917 | CV10_R2=0.605 | OOD_R2=0.210 | Overfit_suspected
#
# === Processing Rborist-like RF: m_base_FP_rebuilt.csv ===
#   [Cleaning] Removed 40 duplicated features (corr>0.99999)
#   Target=Jsc | Train_R2=0.922 | CV10_R2=0.702 | OOD_R2=0.044 | Overfit_suspected
#   [Cleaning] Removed 40 duplicated features (corr>0.99999)
#   Target=Voc | Train_R2=0.950 | CV10_R2=0.731 | OOD_R2=0.051 | Overfit_suspected
#   [Cleaning] Removed 40 duplicated features (corr>0.99999)
#   Target=FF | Train_R2=0.885 | CV10_R2=0.548 | OOD_R2=0.110 | Overfit_suspected
#   [Cleaning] Removed 40 duplicated features (corr>0.99999)
#   Target=PCEmax | Train_R2=0.915 | CV10_R2=0.699 | OOD_R2=-0.005 | Overfit_suspected
#
# === Processing Rborist-like RF: m_all.csv ===
#   Target=Jsc | Train_R2=0.949 | CV10_R2=0.606 | OOD_R2=0.341 | Overfit_suspected
#   Target=Voc | Train_R2=0.935 | CV10_R2=0.537 | OOD_R2=0.251 | Overfit_suspected
#   Target=FF | Train_R2=0.931 | CV10_R2=0.478 | OOD_R2=0.454 | Overfit_suspected
#   Target=PCEmax | Train_R2=0.952 | CV10_R2=0.638 | OOD_R2=0.374 | Overfit_suspected
#
# === Processing Rborist-like RF: m_all_OH_rebuilt.csv ===
#   [Cleaning] Removed 3 duplicated features (corr>0.99999)
#   Target=Jsc | Train_R2=0.951 | CV10_R2=0.640 | OOD_R2=0.397 | Overfit_suspected
#   [Cleaning] Removed 3 duplicated features (corr>0.99999)
#   Target=Voc | Train_R2=0.939 | CV10_R2=0.558 | OOD_R2=0.277 | Overfit_suspected
#   [Cleaning] Removed 3 duplicated features (corr>0.99999)
#   Target=FF | Train_R2=0.932 | CV10_R2=0.503 | OOD_R2=0.514 | Overfit_suspected
#   [Cleaning] Removed 3 duplicated features (corr>0.99999)
#   Target=PCEmax | Train_R2=0.955 | CV10_R2=0.653 | OOD_R2=0.417 | Overfit_suspected
#
# === Processing Rborist-like RF: m_all_FP_rebuilt.csv ===
#   [Cleaning] Removed 42 duplicated features (corr>0.99999)
#   Target=Jsc | Train_R2=0.961 | CV10_R2=0.700 | OOD_R2=0.432 | Overfit_suspected
#   [Cleaning] Removed 42 duplicated features (corr>0.99999)
#   Target=Voc | Train_R2=0.950 | CV10_R2=0.624 | OOD_R2=0.508 | Overfit_suspected
#   [Cleaning] Removed 42 duplicated features (corr>0.99999)
#   Target=FF | Train_R2=0.937 | CV10_R2=0.529 | OOD_R2=0.528 | Overfit_suspected
#   [Cleaning] Removed 42 duplicated features (corr>0.99999)
#   Target=PCEmax | Train_R2=0.963 | CV10_R2=0.716 | OOD_R2=0.479 | Overfit_suspected
#
# [DONE]
# Summary : ./20251218_Rebuilt_12Files_RboristLikeRF_Train_CV10OOF_OOD/fixed_20251218_RboristLikeRF_summary.csv
# Imp     : ./20251218_Rebuilt_12Files_RboristLikeRF_Train_CV10OOF_OOD/fixed_20251218_RboristLikeRF_feature_importance.csv

# %%
#badpredID

# %%
import joblib
import pandas as pd
import numpy as np
import os
from datetime import datetime
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.inspection import permutation_importance

# --- Seed固定 ---
np.random.seed(42)

# --- 設定 ---
base_path = "/Volumes/csbdeep11/_yasu-i/20250303_rebuiled/20220127_PLS 202201 ALL/20251216_for_making_collect_data_nm_baseall_OHFP_csv/rebuilt_merged_data/"

file_names = [
    "n_base.csv", "n_base_OH_rebuilt.csv", "n_base_FP_rebuilt.csv",
    "n_all.csv",  "n_all_OH_rebuilt.csv",  "n_all_FP_rebuilt.csv",
    "m_base.csv", "m_base_OH_rebuilt.csv", "m_base_FP_rebuilt.csv",
    "m_all.csv",  "m_all_OH_rebuilt.csv",  "m_all_FP_rebuilt.csv"
]

target_vars = ["Jsc", "Voc", "FF", "PCEmax"]
today = datetime.now().strftime("%Y%m%d")

# 【新条件】出力先フォルダの設定 (日付付きフォルダ)
folder_name = f"{today}_Rebuilt_12Files_Results"
output_path = os.path.join("./", folder_name)
os.makedirs(output_path, exist_ok=True)

print(f"Output Folder: {output_path}")

# --- 関数定義 ---

def create_ood_split(df, feature_cols, ood_ratio=0.1):
    X = df[feature_cols].values
    centroid = np.mean(X, axis=0)
    distances = np.linalg.norm(X - centroid, axis=1)
    num_ood = max(1, int(len(df) * ood_ratio))
    ood_indices = np.argsort(distances)[-num_ood:]
    df_train = df.drop(df.index[ood_indices])
    df_test = df.iloc[ood_indices]
    return df_train, df_test

def remove_collinear_features(df, feature_cols, threshold=0.99999):
    if len(feature_cols) < 2: return feature_cols
    X = df[feature_cols]
    corr_matrix = X.corr().abs()
    corr_matrix = corr_matrix.fillna(0)
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
    if len(to_drop) > 0:
        print(f"  [Cleaning] Removed {len(to_drop)} duplicated features")
    return [c for c in feature_cols if c not in to_drop]

# --- メイン処理 ---
summary_data = []
feature_importance_data = []

print(f"--- RF Analysis Started: {today} ---")
print(f"Path: {base_path}")

for file in file_names:
    input_file = os.path.join(base_path, file)
    if not os.path.exists(input_file):
        print(f"Skipping: {file} (Not found)")
        continue
        
    print(f"\n=== Processing RF: {file} ===")
    
    try:
        # ID列(X)をインデックスとして読み込む
        df_raw = pd.read_csv(input_file, index_col=0).drop(columns=['X'], errors='ignore')
    except Exception as e:
        print(f"Error reading {file}: {e}")
        continue
    
    for target in target_vars:
        if target not in df_raw.columns: continue
        
        # 1. データ整理
        df_temp = df_raw.select_dtypes(include=[np.number]).dropna()
        feature_cols = [c for c in df_temp.columns if c not in target_vars]
        variances = df_temp[feature_cols].var()
        feature_cols = variances[variances > 0].index.tolist()
        feature_cols = remove_collinear_features(df_temp, feature_cols)
        
        if len(df_temp) < 20 or len(feature_cols) == 0: continue

        # 2. OOD分割
        df_train, df_test = create_ood_split(df_temp, feature_cols, ood_ratio=0.1)

        # 3. スケーリング
        scaler = MinMaxScaler(feature_range=(-1, 1))
        X_train_scaled = scaler.fit_transform(df_train[feature_cols])
        y_train = df_train[target]
        X_test_scaled = scaler.transform(df_test[feature_cols])
        y_test = df_test[target]

        # 4. モデル構築 (RF)
        rf = RandomForestRegressor(n_estimators=500, random_state=42)
        param_grid = {
            'max_features': [1, 3, 5, 'sqrt'], 
            'min_samples_leaf': [1, 3, 5]
        }

        grid = GridSearchCV(
            rf, param_grid, cv=KFold(10, shuffle=True, random_state=42), 
            scoring='neg_mean_squared_error', n_jobs=-1
        )
        grid.fit(X_train_scaled, y_train)
        best_model = grid.best_estimator_
        
        # 5. 評価
        y_pred_train = best_model.predict(X_train_scaled)
        r2 = r2_score(y_train, y_pred_train)
        rmse_val = np.sqrt(mean_squared_error(y_train, y_pred_train))
        mae_val = mean_absolute_error(y_train, y_pred_train)
        rpd = np.std(y_train) / rmse_val if rmse_val != 0 else 0

        y_pred_ood = best_model.predict(X_test_scaled)
        ood_r2 = r2_score(y_test, y_pred_ood)
        ood_rmse = np.sqrt(mean_squared_error(y_test, y_pred_ood))

        summary_data.append({
            "File": file, "Target": target, 
            "R2": r2, "RMSE": rmse_val, "MAE": mae_val, "RPD": rpd,
            "n_samples": len(df_temp), "n_features": len(feature_cols),
            "OOD_R2": ood_r2, "OOD_RMSE": ood_rmse, 
            "Best_Params": str(grid.best_params_)
        })

        # 6. 変数重要度
        print(f"  Computing importance for {target}...")
        perm_importance = permutation_importance(
            best_model, X_train_scaled, y_train, 
            n_repeats=5, random_state=42, n_jobs=-1
        )
        
        indices = np.argsort(perm_importance.importances_mean)[::-1]
        for idx in indices:
            val = perm_importance.importances_mean[idx]
            if val > 1e-5: 
                feature_importance_data.append({
                    "File": file, "Target": target,
                    "Feature": feature_cols[idx],
                    "Importance_Mean": val,
                    "Importance_Std": perm_importance.importances_std[idx]
                })

        print(f"  Target: {target} | R2: {r2:.3f} | OOD_R2: {ood_r2:.3f}")
        
        # --- (新条件) 保存処理 ---
        # 1. モデルの保存
        model_filename = f"fixed_{today}_RF_{file.replace('.csv', '')}_{target}_model.joblib"
        joblib.dump(best_model, os.path.join(output_path, model_filename))

        # 2. プロット用データの保存 (SampleIDを追加)
        df_pred = pd.DataFrame({
            'SampleID': np.concatenate([y_train.index, y_test.index]), # SampleIDを保存
            'Observed': np.concatenate([y_train.values, y_test.values]),
            'Predicted': np.concatenate([y_pred_train, y_pred_ood]),
            'Type': ['Train'] * len(y_train) + ['OOD_Test'] * len(y_test)
        })
        pred_filename = f"fixed_{today}_RF_{file.replace('.csv', '')}_{target}_pred.csv"
        df_pred.to_csv(os.path.join(output_path, pred_filename), index=False)

# --- 保存 ---
df_sum = pd.DataFrame(summary_data)
path_sum = os.path.join(output_path, f"fixed_{today}_RF_summary.csv")
df_sum.to_csv(path_sum, index=False)

df_imp = pd.DataFrame(feature_importance_data)
path_imp = os.path.join(output_path, f"fixed_{today}_RF_feature_importance.csv")
df_imp.to_csv(path_imp, index=False)

print(f"\nRF Process Finished.\nSummary: {path_sum}")
# Out:
# Output Folder: ./20251217_Rebuilt_12Files_Results
# --- RF Analysis Started: 20251217 ---
# Path: /Volumes/csbdeep11/_yasu-i/20250303_rebuiled/20220127_PLS 202201 ALL/20251216_for_making_collect_data_nm_baseall_OHFP_csv/rebuilt_merged_data/
#
# === Processing RF: n_base.csv ===
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.860 | OOD_R2: 0.587
#   Computing importance for Voc...
#   Target: Voc | R2: 0.927 | OOD_R2: 0.649
#   Computing importance for FF...
#   Target: FF | R2: 0.774 | OOD_R2: -0.712
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.833 | OOD_R2: 0.714
#
# === Processing RF: n_base_OH_rebuilt.csv ===
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.900 | OOD_R2: 0.557
#   Computing importance for Voc...
#   Target: Voc | R2: 0.940 | OOD_R2: 0.562
#   Computing importance for FF...
#   Target: FF | R2: 0.812 | OOD_R2: -0.262
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.883 | OOD_R2: 0.626
#
# === Processing RF: n_base_FP_rebuilt.csv ===
#   [Cleaning] Removed 46 duplicated features
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.870 | OOD_R2: 0.716
#   [Cleaning] Removed 46 duplicated features
#   Computing importance for Voc...
#   Target: Voc | R2: 0.936 | OOD_R2: 0.586
#   [Cleaning] Removed 46 duplicated features
#   Computing importance for FF...
#   Target: FF | R2: 0.782 | OOD_R2: -0.133
#   [Cleaning] Removed 46 duplicated features
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.846 | OOD_R2: 0.610
#
# === Processing RF: n_all.csv ===
#   [Cleaning] Removed 9 duplicated features
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.741 | OOD_R2: 0.052
#   [Cleaning] Removed 9 duplicated features
#   Computing importance for Voc...
#   Target: Voc | R2: 0.955 | OOD_R2: -0.074
#   [Cleaning] Removed 9 duplicated features
#   Computing importance for FF...
#   Target: FF | R2: 0.863 | OOD_R2: 0.126
#   [Cleaning] Removed 9 duplicated features
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.704 | OOD_R2: 0.016
#
# === Processing RF: n_all_OH_rebuilt.csv ===
#   [Cleaning] Removed 12 duplicated features
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.927 | OOD_R2: 0.383
#   [Cleaning] Removed 12 duplicated features
#   Computing importance for Voc...
#   Target: Voc | R2: 0.957 | OOD_R2: -0.040
#   [Cleaning] Removed 12 duplicated features
#   Computing importance for FF...
#   Target: FF | R2: 0.874 | OOD_R2: 0.126
#   [Cleaning] Removed 12 duplicated features
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.911 | OOD_R2: 0.374
#
# === Processing RF: n_all_FP_rebuilt.csv ===
#   [Cleaning] Removed 46 duplicated features
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.752 | OOD_R2: 0.232
#   [Cleaning] Removed 46 duplicated features
#   Computing importance for Voc...
#   Target: Voc | R2: 0.959 | OOD_R2: 0.166
#   [Cleaning] Removed 46 duplicated features
#   Computing importance for FF...
#   Target: FF | R2: 0.865 | OOD_R2: 0.163
#   [Cleaning] Removed 46 duplicated features
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.908 | OOD_R2: 0.446
#
# === Processing RF: m_base.csv ===
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.889 | OOD_R2: 0.065
#   Computing importance for Voc...
#   Target: Voc | R2: 0.766 | OOD_R2: 0.520
#   Computing importance for FF...
#   Target: FF | R2: 0.855 | OOD_R2: 0.130
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.883 | OOD_R2: -0.020
#
# === Processing RF: m_base_OH_rebuilt.csv ===
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.927 | OOD_R2: 0.348
#   Computing importance for Voc...
#   Target: Voc | R2: 0.941 | OOD_R2: 0.407
#   Computing importance for FF...
#   Target: FF | R2: 0.892 | OOD_R2: 0.203
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.921 | OOD_R2: 0.289
#
# === Processing RF: m_base_FP_rebuilt.csv ===
#   [Cleaning] Removed 40 duplicated features
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.922 | OOD_R2: 0.124
#   [Cleaning] Removed 40 duplicated features
#   Computing importance for Voc...
#   Target: Voc | R2: 0.950 | OOD_R2: 0.078
#   [Cleaning] Removed 40 duplicated features
#   Computing importance for FF...
#   Target: FF | R2: 0.890 | OOD_R2: 0.051
#   [Cleaning] Removed 40 duplicated features
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.918 | OOD_R2: 0.155
#
# === Processing RF: m_all.csv ===
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.944 | OOD_R2: 0.333
#   Computing importance for Voc...
#   Target: Voc | R2: 0.933 | OOD_R2: 0.235
#   Computing importance for FF...
#   Target: FF | R2: 0.928 | OOD_R2: 0.397
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.948 | OOD_R2: 0.355
#
# === Processing RF: m_all_OH_rebuilt.csv ===
#   [Cleaning] Removed 3 duplicated features
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.945 | OOD_R2: 0.348
#   [Cleaning] Removed 3 duplicated features
#   Computing importance for Voc...
#   Target: Voc | R2: 0.933 | OOD_R2: 0.272
#   [Cleaning] Removed 3 duplicated features
#   Computing importance for FF...
#   Target: FF | R2: 0.930 | OOD_R2: 0.429
#   [Cleaning] Removed 3 duplicated features
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.949 | OOD_R2: 0.370
#
# === Processing RF: m_all_FP_rebuilt.csv ===
#   [Cleaning] Removed 42 duplicated features
#   Computing importance for Jsc...
#   Target: Jsc | R2: 0.958 | OOD_R2: 0.449
#   [Cleaning] Removed 42 duplicated features
#   Computing importance for Voc...
#   Target: Voc | R2: 0.947 | OOD_R2: 0.527
#   [Cleaning] Removed 42 duplicated features
#   Computing importance for FF...
#   Target: FF | R2: 0.937 | OOD_R2: 0.528
#   [Cleaning] Removed 42 duplicated features
#   Computing importance for PCEmax...
#   Target: PCEmax | R2: 0.962 | OOD_R2: 0.457
#
# RF Process Finished.
# Summary: ./20251217_Rebuilt_12Files_Results/fixed_20251217_RF_summary.csv
